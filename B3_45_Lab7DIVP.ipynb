# %%
#Pranay Nimje
#B3-45
#Practical 7

# %%
# to study and perform image segmentation using following detection techniques
# 1) horizontal line detection
# 2) vertical lines detection
# 3) canny edge detector
# 4) hough transformation.

# %%
#horizontal lines
import cv2
import matplotlib.pyplot as plt
import numpy as np
from google.colab.patches import cv2_imshow

img=cv2.imread("/content/drive/MyDrive/Dip lab/lines.png")
plt.title("original image")
plt.imshow(img)
plt.show()
w,h,d=img.shape
print(w,h,d)
kernel=np.ones((2,20),np.uint8)
eroded=cv2.erode(img,kernel,iterations=1)
plt.title("eroded image : horizontal lines")
plt.imshow(eroded)
plt.show()
# Out:
# 266 226 3

# %%
#horizontal lines
import cv2
import matplotlib.pyplot as plt
import numpy as np
from google.colab.patches import cv2_imshow

img=cv2.imread("/content/drive/MyDrive/Dip lab/lines.png")
plt.title("original image")
plt.imshow(img)
plt.show()
w,h,d=img.shape
print(w,h,d)
kernel=np.ones((20,2),np.uint8)
eroded=cv2.erode(img,kernel,iterations=1)
plt.title("eroded image : vertical lines")
plt.imshow(eroded)
plt.show()
# Out:
# 266 226 3

# %%
# canny edge detection
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

img = cv2.imread('/content/tiger.jpg')
cv2_imshow(img)

canny = cv2.Canny(img, 100, 200)
cv2_imshow(canny)
# Out:
# <PIL.Image.Image image mode=RGB size=472x341>
# <PIL.Image.Image image mode=L size=472x341>

# %%
# houge transformation
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
# Read image
img = cv2.imread('/content/drive/MyDrive/Dip lab/lines.png',cv2.IMREAD_COLOR) # road.png is the filename

# Convert the image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# Find the edges in the image using canny detector
edges = cv2.Canny(gray, 50, 200)

# Detect points that form a line
#lines = cv2.HoughLinesP(edges, 1, np.pi/180, 68, minLineLength=15, maxLineGap=250)
lines = cv2.HoughLinesP(edges, 1, np.pi/180, 25, minLineLength=15, maxLineGap=250)
# Draw lines on the image
for line in lines:
   x1, y1, x2, y2 = line[0]
   cv2.line(img, (x1, y1), (x2, y2), (0, 90, 255), 3)
# Show result
print("Line Detection using Hough Transform")
cv2_imshow(img)
# Out:
# Line Detection using Hough Transform
# <PIL.Image.Image image mode=RGB size=226x266>
